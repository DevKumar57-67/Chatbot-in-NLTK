# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/text-document-classification-dataset/df_file.csv

# %% [markdown]
# > PROJECT--- BUILDING NLP BASED CHATBOT USING NLTK

# %%
#installation 

# !pip install pdfminer.six
# !pip install fpdf
# Out:
# Collecting pdfminer.six
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from pdfminer.six) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /opt/conda/lib/python3.10/site-packages (from pdfminer.six) (41.0.7)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.10/site-packages (from cryptography>=36.0.0->pdfminer.six) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.21)
# Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 72.2 MB/s eta 0:00:00
# Installing collected packages: pdfminer.six
# Successfully installed pdfminer.six-20231228
# Collecting fpdf
#   Downloading fpdf-1.7.2.tar.gz (39 kB)
# done
# Building wheels for collected packages: fpdf
# done
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40703 sha256=ef24ccf2f70153204b0dd9c0ce4487ef121f2dad29ba8c3c2cb3927225bfdb6d
#   Stored in directory: /root/.cache/pip/wheels/f9/95/ba/f418094659025eb9611f17cbcaf2334236bf39a0c3453ea455
# Successfully built fpdf
# Installing collected packages: fpdf
# Successfully installed fpdf-1.7.2

# %%
#importing libraries 

import numpy as np
import pandas as pd
import string
import nltk
import random

# %% [markdown]
#     LOADING DATASET

# %%
df=pd.read_csv("/kaggle/input/text-document-classification-dataset/df_file.csv")
df
# Out:
#                                                    Text  Label
# 0     Budget to set scene for election\n \n Gordon B...      0
# 1     Army chiefs in regiments decision\n \n Militar...      0
# 2     Howard denies split over ID cards\n \n Michael...      0
# 3     Observers to monitor UK election\n \n Minister...      0
# 4     Kilroy names election seat target\n \n Ex-chat...      0
# ...                                                 ...    ...
# 2220  India opens skies to competition\n \n India wi...      4
# 2221  Yukos bankruptcy 'not US matter'\n \n Russian ...      4
# 2222  Survey confirms property slowdown\n \n Governm...      4
# 2223  High fuel prices hit BA's profits\n \n British...      4
# 2224  US trade gap hits record in 2004\n \n The gap ...      4
#
# [2225 rows x 2 columns]

# %% [markdown]
#     DATA ANALYTICS:

# %%
df.head()
# Out:
#                                                 Text  Label
# 0  Budget to set scene for election\n \n Gordon B...      0
# 1  Army chiefs in regiments decision\n \n Militar...      0
# 2  Howard denies split over ID cards\n \n Michael...      0
# 3  Observers to monitor UK election\n \n Minister...      0
# 4  Kilroy names election seat target\n \n Ex-chat...      0

# %%
df.shape
# Out:
# (2225, 2)

# %%
#value_counts 

df['Text'].value_counts()
# Out:
# Text
# Kenyan school turns to handhelds\n \n At the Mbita Point primary school in western Kenya students click away at a handheld computer with a stylus.\n \n They are doing exercises in their school textbooks which have been digitised. It is a pilot project run by EduVision, which is looking at ways to use low cost computer systems to get up-to-date information to students who are currently stuck with ancient textbooks. Matthew Herren from EduVision told the BBC programme Go Digital how the non-governmental organisation uses a combination of satellite radio and handheld computers called E-slates. "The E-slates connect via a wireless connection to a base station in the school. This in turn is connected to a satellite radio receiver. The data is transmitted alongside audio signals." The base station processes the information from the satellite transmission and turns it into a form that can be read by the handheld E-slates. "It downloads from the satellite and every day processes the stream, sorts through content for the material destined for the users connected to it. It also stores this on its hard disc."\n \n The system is cheaper than installing and maintaining an internet connection and conventional computer network. But Mr Herren says there are both pros and cons to the project. "It's very simple to set up, just a satellite antenna on the roof of the school, but it's also a one-way connection, so getting feedback or specific requests from end users is difficult."\n \n The project is still at the pilot stage and EduVision staff are on the ground to attend to teething problems with the Linux-based system. "The content is divided into visual information, textual information and questions. Users can scroll through these sections independently of each other." EduVision is planning to include audio and video files as the system develops and add more content. Mr Herren says this would vastly increase the opportunities available to the students. He is currently in negotiations to take advantage of a project being organised by search site Google to digitise some of the world's largest university libraries. "All books in the public domain, something like 15 million, could be put on the base stations as we manufacture them. Then every rural school in Africa would have access to the same libraries as the students in Oxford and Harvard" Currently the project is operating in an area where there is mains electricity. But Mr Herren says EduVision already has plans to extend it to more remote regions. "We plan to put a solar panel at the school with the base station, have the E-slates charge during the day when the children are in school, then they can take them home at night and continue working." Maciej Sundra, who designed the user interface for the E-slates, says the project's ultimate goal is levelling access to knowledge around the world. "Why in this age when most people do most research using the internet are students still using textbooks? The fact that we are doing this in a rural developing country is very exciting - as they need it most."\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# Commodore finds new lease of life\n \n The once-famous Commodore computer brand could be resurrected after being bought by a US-based digital music distributor.\n \n New owner Yeahronimo Media Ventures has not ruled out the possibility of a new breed of Commodore computers. It also plans to develop a "worldwide entertainment concept" with the brand, although details are not yet known. The groundbreaking Commodore 64 computer elicits fond memories for those who owned one back in the 1980s.\n \n In the chronology of home computing, Commodore was one of the pioneers.\n \n The Commodore 64, launched in 1982, was one of the first affordable home PCs. It was followed a few years later by the Amiga. The Commodore 64 sold more than any other single computer system, even to this day. The brand languished somewhat in the 1990s. Commodore International filed for bankruptcy in 1994 and was sold to Dutch firm Tulip Computers. In the late 1980s the firm was a great rival to Atari, which produced its own range of home computers and is now a brand of video games, formerly known as Infogrames.\n \n Tulip Computers sold several products under the Commodore name, including portable USB storage devices and digital music players. It had planned to relaunch the brand, following an upsurge of nostalgia for 1980s-era games. Commodore 64 enthusiasts have written emulators for Windows PC, Apple Mac and even PDAs so that the original Commodore games can be still run. The sale of Commodore is expected to be complete in three weeks in a deal worth over Â£17m.\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# Doors open at biggest gadget fair\n \n Thousands of technology lovers and industry experts have gathered in Las Vegas for the annual Consumer Electronics Show (CES).\n \n The fair showcases the latest technologies and gadgets that will hit the shops in the next year. About 50,000 new products will be unveiled as the show unfolds. Microsoft chief Bill Gates is to make a pre-show keynote speech on Wednesday when he is expected to announce details of the next generation Xbox.\n \n The thrust of this year's show will be on technologies which put people in charge of multimedia content so they can store, listen to, and watch what they want on devices any time, anywhere. About 120,000 people are expected to attend the trade show which stretches over more than 1.5 million square feet. Highlights will include the latest trends in digital imaging, storage technologies, thinner flat screen and high-definition TVs, wireless and portable technologies, gaming, and broadband technologies. The show also includes several speeches from key technology companies such as Intel, Microsoft, and Hewlett Packard among others. "The story this year remains all about digital and how that is completely transforming and revolutionising products and the way people interact with them," Jeff Joseph, from the Consumer Electronics Association (CEA) told the BBC News website. "It is about personalisation - taking your MP3 player and creating your own playlist, taking your digital video recorder and watch what you want to watch when - you are no longer at the whim of the broadcasters."\n \n Consumer electronics and gadgets had a phenomenal year in 2004, according to figures released by CES organisers, the CEA, on Tuesday. The gadget explosion signalled the strongest growth yet in the US in 2004. Shipments of consumer electronics rose by almost 11% between 2003 and 2004. That trend is predicted to continue, according to CEA analysts, with wholesale shipments of consumer technologies expected to grow by 11% again in 2005. The fastest-growing technologies in 2004 included blank DVD media, Liquid Crystal Display (LCD) TVs, digital video recorders (DVRs), and portable music players. "This year we will really begin to see that come to life in what we call place shifting - so if you have your PVR [personal video recorder] in your living room, you can move that content around the house. "Some exhibitors will be showcasing how you can take that content anywhere," said Mr Joseph. He said the products which will be making waves in the next year will be about the "democratisation" of content - devices and technologies that will give people the freedom to do more with music, video, and images. There will also be more focus on the design of technologies, following the lead that Apple's iPod made, with ease of use and good looks which appeal to a wider range of people a key concern.\n \n The CEA predicted that there would be several key technology trends to watch in the coming year. Gaming would continue to thrive, especially on mobile devices, and would reach out to more diverse gamers such as women. Games consoles sales have been declining, but the launch of next generation consoles, such as Microsoft's Xbox and PlayStation, could buoy up sales. Although it has been widely predicted that Mr Gates would be showcasing the new Xbox, some media reports have cast doubt on what he would be talking about in the keynote. Some have suggested the announcement may take place at the Games Developers Conference in the summer instead. With more than 52% of US homes expected to have home networks, the CEA suggested hard drive boxes - or media servers - capable of storing thousands of images, video and audio files to be accessed through other devices around the home, will be more commonplace. Portable devices that combine mobile telephony, digital music and video players, will also be more popular in 2005. Their popularity will be driven by more multimedia content and services which will let ...
# Warning over tsunami aid website\n \n Net users are being told to avoid a scam website that claims to collect cash on behalf of tsunami victims.\n \n The site looks plausible because it uses an old version of the official Disasters Emergency Committee webpage. However, DEC has no connection with the fake site and says it has contacted the police about it. The site is just the latest in a long list of scams that try to cash in on the goodwill generated by the tsunami disaster.\n \n The link to the website is contained in a spam e-mail that is currently circulating. The message's subject line reads "Urgent Tsunami Earthquake Appeal" and its text bears all the poor grammar and bad spelling that characterises many other phishing attempts. The web address of the fake site is decuk.org which could be close enough to the official www.dec.org.uk address to confuse some people keen to donate. Patricia Sanders, spokeswoman for the Disaster Emergency Committee said it was aware of the site and had contacted the Computer Crime Unit at Scotland Yard to help get it shut down. She said the spam e-mails directing people to the site started circulating two days ago shortly after the domain name of the site was registered. It is thought that the fake site is being run from Romania. Ms Sanders said DEC had contacted US net registrars who handle domain ownership and the net hosting firm that is keeping the site on the web.\n \n DEC was going to push for all cash donated via the site to be handed over to the official organisation. BT and DEC's hosting company were also making efforts to get the site shut down, she said.\n \n Ms Sanders said sending out spam e-mail to solicit donations was not DEC's style and that it would never canvass support in this way. She said that DEC hoped to get the fake site shut down as soon as possible. All attempts by the BBC News website to contact the people behind the site have failed. None of the e-mail addresses supplied on the site work and the real owner of the domain is obscured in publicly available net records. This is not the first attempt to cash in on the outpouring of goodwill that has accompanied appeals for tsunami aid. One e-mail sent out in early January came from someone who claimed that he had lost his parents in the disaster and was asking for help moving an inheritance from a bank account in the Netherlands. The con was very similar to the familiar Nigerian forward fee fraud e-mails that milk money out of people by promising them a cut of a much larger cash pile. Other scam e-mails included a link to a website that supposedly let people donate money but instead loaded spyware on their computers that grabbed confidential information. In a monthly report anti-virus firm Sophos said that two e-mail messages about the tsunami made it to the top 10 hoax list during January. Another tsunami-related e-mail is also circulating that carries the Zar worm which tries to spread via the familiar route of Microsoft's Outlook e-mail program. Anyone opening the attachment of the mail will have their contact list plundered by the worm keen to find new addresses to send itself to.\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# Junk e-mails on relentless rise\n \n Spam traffic is up by 40%, putting the total amount of e-mail that is junk up to an astonishing 90%.\n \n The figures, from e-mail management firm Email Systems, will alarm firms attempting to cope with the amount of spam in their in-boxes. While virus traffic has slowed down, denial of service attacks are on the increase according to the firm. Virus mail accounts for just over 15% of all e-mail traffic analysis by the firm has found.\n \n It is no longer just multi-nationals that are in danger of so-called denial of service attacks, in which websites are bombarded by requests for information and rendered inaccessible. Email Systems refers to a small UK-based engineering firm, which received a staggering 12 million e-mails in January. The type of spam currently being sent has subtlety altered in the last few months, according to Email Systems analysis. Half of spam received since Christmas has been health-related with gambling and porn also on the increase. Scam mails, offering ways to make a quick buck, have declined by 40%. "January is clearly a month when consumers are less motivated to purchase financial products or put money into dubious financial opportunities," said Neil Hammerton, managing director of Email Systems. "Spammers seem to have adapted their output to reflect this, focussing instead on medically motivated and pornographic offers, presumably intentionally intended to coincide with what is traditionally considered to be the bleakest month in the calendar," he said.\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# Italy 17-28 Ireland\n \n Two moments of magic from Brian O'Driscoll guided Ireland to a workmanlike victory against Italy.\n \n A pair of classic outside breaks from the Ireland captain set up tries for Geordan Murphy and Peter Stringer. Italy led 9-8 early in the second half but Stringer's try gave Ireland a lead they never lost. The hosts cut the gap to 18-12 with 10 minutes left and nearly scored through Ludovico Nitoglia, but Denis Hickie's try ensured an Irish victory. Italy came flying out of the blocks and took the lead through a Luciano Orquera penalty after seven minutes.\n \n It could have been better for the hosts but the fly-half missed two kickable penalties and Ireland drew level with a Ronan O'Gara penalty midway through the first half. The Italians were driving at the heart of the Irish defence and, for the first quarter, the Irish pack struggled to secure any ball for their talented backs.\n \n When they finally did, just before the half-hour mark, O'Driscoll promptly created a sparkling try for Murphy. The Ireland captain ran a dummy scissors and made a magical outside break before drawing the full-back and putting the diving Murphy in at the corner. O'Gara missed the twice-taken conversion and the visitors found themselves trailing once again. Roland de Marigny took over the kicking duties for Italy from the hapless Orquera, and he landed a penalty either side of the break to edge Italy into a 9-8 lead.\n \n The only Ireland player offering a real threat was O'Driscoll, and it was his break that set up the second try for the visitors. Shane Horgan threw an overhead pass as he was about to be forced into touch and Stringer scooted over, with O'Gara landing the tricky conversion. A penalty apiece saw Ireland leading 18-12 as the game entered the final quarter, but they were lucky to survive when Italy launched a series of attacks. Winger Nitoglia dropped the ball as he reached for the line and Italy nearly rumbled over from a driving maul.\n \n An O'Gara penalty put Ireland more than a converted try ahead and they made the game safe when Hickie latched onto an inside pass from Murphy and crossed for a converted try. O'Driscoll limped off late on, joining centre partner Gordon D'Arcy on the sidelines, and the final word went to Italy. Prop Martin Castrogiovanni powered over for a try which was fitting reward for an Italian pack which had kept the Irish under pressure throughout.\n \n De Marigny; Mi Bergamasco, Canale, Masi, Nitoglia; Orquera, Troncon; Lo Cicero, Ongaro, Castrogiovanni; Dellape, Bortolami; Persico, Ma Bergamasco, Parisse.\n \n Perugini, Intoppa, Del Fava, Dal Maso, Griffen, Pozzebon, Robertson.\n \n Murphy, Horgan, O'Driscoll, D'Arcy, Hickie, O'Gara, Stringer, Corrigan, Byrne, Hayes, O'Kelly, O'Connell, S Easterby, Leamy, Foley.\n \n Sheahan, Horan, O'Callaghan, Miller, G Easterby, Humphreys, Dempsey.\n \n P O'Brien (New Zealand)\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# Chelsea ridiculed over complaint\n \n Barcelona assistant coach Henk Ten Cate has branded Chelsea's expected complaint to Uefa as "pathetic".\n \n The Blues are poised to complain about an alleged half-time incident during Wednesday's 2-1 loss at the Nou Camp. The source of Chelsea's anger was an alleged talk between Barca boss Frank Rijkaard and referee Anders Frisk, who later dismissed Didier Drogba. "To react the way Chelsea have is pathetic. Mourinho lied with the line-ups, and now this," Ten Cate said. Uefa has said its own tunnel representative witnessed nothing unusual out of the ordinary during the half-time break. Spokesman William Gaillard said: "Frisk says Rijkaard greeted him and apologised he had not had the opportunity to say hello before the game. "We had two Uefa officials there and neither witnessed it. The referee's dressing room was locked and he and his assistants were the only people allowed in." Indeed, it is the Londoners who could be on the receiving end of any punishment after failing to turn up for the compulsory press conference after the defeat.\n \n Uefa delegate Thomas Giordano added: "The only unusual thing that happened as far as we are concerned is that Chelsea failed to present themselves in the press conference." The referee is not expected to include any of the alleged incidents in his report to Uefa - weakening Chelsea's case. Rijkaard was critical of Mourinho's decision not to speak to the media after the match. "There was a lot of talking before the game and now surprisingly there is a lot of talking after the game. It is not good behaviour after a match," he said. "Maybe they want to start something and make it worse than than it is. I really don't understand it. I am very calm about it."\n \n Barca midfielder Deco, formerly managed by Mourinho at Porto, agreed that it was not typical of his fellow Portuguese to lodge a protest. "It's not normal behaviour on his part. It was not logical he did not give a news conference," he said. Rijkaard added: "Chelsea is the team which has conceded fewest goals in the English league and they defend very well so I am very pleased with the win. "My men deserved victory and I am pleased to have won this match. I congratulate my players."\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# Benitez deflects blame from Dudek\n \n Liverpool manager Rafael Benitez has refused to point the finger of blame at goalkeeper Jerzy Dudek after Portsmouth claimed a draw at Anfield.\n \n Dudek fumbled a cross before Lomana LuaLua headed home an injury-time equaliser, levelling after Steven Gerrard put Liverpool ahead. Benitez said: "It was difficult for Jerzy. It was an unlucky moment. "He was expecting a cross from Matthew Taylor and it ended up like a shot, so I don't blame him for what happened." Benitez admitted it was a costly loss of two points by Liverpool, who followed up their derby defeat against Everton with a disappointing draw. He said: "We had many opportunities but didn't score and, in the end, a 1-0 lead was not enough. "If you don't have any chances you have to think of other things, but when you are creating so many chances as we are there is nothing you can say to the players. It was a pity. "We lost two points, but we have one more point in the table. Now we have another difficult game against Newcastle and we have to recover quickly from that."\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# Dogged Federer claims Dubai crown\n \n World number one Roger Federer added the Dubai Championship trophy to his long list of successes - but not before he was given a test by Ivan Ljubicic.\n \n Top seed Federer looked to be on course for a easy victory when he thumped the eighth seed 6-1 in the first set. But Ljubicic, who beat Tim Henman in the last eight, dug deep to secure the second set after a tense tiebreak. Swiss star Federer was not about to lose his cool, though, turning on the style to win the deciding set 6-3. The match was a re-run of last week's final at the World Indoor Tournament in Rotterdam, where Federer triumphed, but not until Ljubicic had stretched him all the way. "I really wanted to get off to a good start this time, and I did, and I could really play with confidence while he still looking for his rhythm," Federer said.\n \n "That took me all the way through to 6-1 3-1 0-30 on his serve and I almost ran away with it. But he came back, and that was a good effort on his side." Ljubicic was at a loss to explain his poor showing in the first set. "I didn't start badly, but then suddenly I felt like my racket was loose and the balls were flying a little bit too much. And with Roger, if you relax for a second it just goes very quick," he said. "After those first three games it was no match at all. I don't know, it was really weird. I was playing really well the whole year, and then suddenly I found myself in trouble just to put the ball in the court." But despite his defeat, the world number 14 was pleased with his overall performance. "I had a chance in the third, and for me it's really positive to twice in two weeks have a chance against Roger to win the match. "It's an absolutely great boost to my confidence that I'm up there and belong with top-class players."\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# Smith aims to bring back respect\n \n Scotland manager Walter Smith says he wants to restore the national team's respectability in world football.\n \n Smith has joined his first squad for a three-day get-together near Manchester in preference to playing a friendly. While qualification for the 2006 World Cup appears to be beyond Scotland, Smith is anxious that the remainder of the campaign should be positive. "I think we have got to try to get a bit of respectability back in whatever way we can," he said. "We will have to approach each game differently. Obviously we will have to approach the Italian game away from home in a different manner to Moldova at home. "We have to meet the challenge of each match." Smith, meeting a number of his squad for the first time, brought them together on Monday to outline his ideas for improving the nation's fortunes.\n \n He said: "I pointed out how I see the international team going forward and that was the main topic. "This is a relaxed gathering and I don't think there is a lot of doom and gloom about the squad that a lot of people think exists." A 25-man squad will spend the next three days based at the Mottram Hall hotel in Cheshire and will train at Manchester United's nearby Carrington complex. Smith will be absent for the final sessions, however, as he is due to fly out to Sardinia on Wednesday to watch Italy's friendly with Russia.\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# Name: count, Length: 2127, dtype: int64

# %% [markdown]
#     CONVERTING TEXT TO PDF:

# %%
#using FPDF

from fpdf import FPDF
pdf=FPDF()
pdf.add_page()
pdf.set_font("Arial",size=12)


for index,row in df.iterrows():
    pdf.cell(200,10,txt=str(row),ln=True,align='L')
    

pdf.output("output.pdf")
# Out:
# ''

# %% [markdown]
# EXTRACTING TEXT FROM PDF:

# %%
#using pdfminer

from pdfminer.high_level import extract_text 
text=extract_text('output.pdf')
print(repr(text))
print(text)
# Out:
# 'Text     Budget to set scene for election\\n \\n Gordon B...(cid:10)Label                                                    0(cid:10)Name: 0, dtype: object\n\nText     Army chiefs in regiments decision\\n \\n Militar...(cid:10)Label                                                    0(cid:10)Name: 1, dtype: object\n\nText     Howard denies split over ID cards\\n \\n Michael...(cid:10)Label                                                    0(cid:10)Name: 2, dtype: object\n\nText     Observers to monitor UK election\\n \\n Minister...(cid:10)Label                                                    0(cid:10)Name: 3, dtype: object\n\nText     Kilroy names election seat target\\n \\n Ex-chat...(cid:10)Label                                                    0(cid:10)Name: 4, dtype: object\n\nText     Donor attacks Blair-Brown \'feud\'\\n \\n The repo...(cid:10)Label                                                    0(cid:10)Name: 5, dtype: object\n\nText     Research fears over Kelly\'s views\\n \\n Scienti...(cid:10)Label                                                    0(cid:10)Name: 6, dtype: object\n\nText     Chancellor rallies Labour voters\\n \\n Gordon B...(cid:10)Label                                                    0(cid:10)Name: 7, dtype: object\n\nText     Fox attacks Blair\'s Tory \'lies\'\\n \\n Tony Blai...(cid:10)Label                                                    0(cid:10)Name: 8, dtype: object\n\nText     Tories unveil quango blitz plans\\n \\n Plans to...(cid:10)Label                                                    0(cid:10)Name: 9, dtype: object\n\nText     Hatfield executives go on trial\\n \\n Engineeri...(cid:10)Label                                                    0(cid:10)Name: 10, dtype: object\n\nText     Howard rejects BNP\'s claim\\n \\n Tory leader Mi...(cid:10)Label                                                    0(cid:10)Name: 11, dtype: object\n\nText     Howard unveils Tory asylum plans\\n \\n Tory pla...(cid:10)Label                                                    0(cid:10)Name: 12, dtype: object\n\nText     Brown and Blair face new rift claims\\n \\n For ...(cid:10)Label                                                    0(cid:10)Name: 13, dtype: object\n\nText     Tories plan migrant health checks\\n \\n Non-Eur...(cid:10)Label                                                    0(cid:10)Name: 14, dtype: object\n\nText     Brown targets OAPs and homebuyers\\n \\n Gordon ...(cid:10)Label                                                    0(cid:10)Name: 15, dtype: object\n\nText     Ministers deny care sums \'wrong\'\\n \\n Minister...(cid:10)Label                                                    0(cid:10)Name: 16, dtype: object\n\nText     Straw praises Kashmir moves\\n \\n The UK has we...(cid:10)Label                                                    0(cid:10)Name: 17, dtype: object\n\nText     Turkey deal \'to help world peace\'\\n \\n A deal ...(cid:10)Label                                                    0(cid:10)Name: 18, dtype: object\n\nText     Goldsmith: \'I was not leant on\'\\n \\n The attor...(cid:10)Label                                                    0(cid:10)Name: 19, dtype: object\n\nText     Escaped prisoner report ordered\\n \\n First Min...(cid:10)Label                                                    0(cid:10)Name: 20, dtype: object\n\nText     Analysis: No pain, no gain?\\n \\n He called it ...(cid:10)Label                                                    0(cid:10)Name: 21, dtype: object\n\nText     Labour accused of \'EU propaganda\'\\n \\n A "taxp...(cid:10)Label                                                    0(cid:10)Name: 22, dtype: object\n\nText     Tories urge \'change at the top\'\\n \\n Tory dele...(cid:10)Label                                                    0(cid:10)Name: 23, dtype: object\n\nText     \'Hitler\' row over Welsh arts cash\\n \\n An arti...(cid:10)Label                                                    0 ...
# Text     Budget to set scene for election\n \n Gordon B...(cid:10)Label                                                    0(cid:10)Name: 0, dtype: object
#
# Text     Army chiefs in regiments decision\n \n Militar...(cid:10)Label                                                    0(cid:10)Name: 1, dtype: object
#
# Text     Howard denies split over ID cards\n \n Michael...(cid:10)Label                                                    0(cid:10)Name: 2, dtype: object
#
# Text     Observers to monitor UK election\n \n Minister...(cid:10)Label                                                    0(cid:10)Name: 3, dtype: object
#
# Text     Kilroy names election seat target\n \n Ex-chat...(cid:10)Label                                                    0(cid:10)Name: 4, dtype: object
#
# Text     Donor attacks Blair-Brown 'feud'\n \n The repo...(cid:10)Label                                                    0(cid:10)Name: 5, dtype: object
#
# Text     Research fears over Kelly's views\n \n Scienti...(cid:10)Label                                                    0(cid:10)Name: 6, dtype: object
#
# Text     Chancellor rallies Labour voters\n \n Gordon B...(cid:10)Label                                                    0(cid:10)Name: 7, dtype: object
#
# Text     Fox attacks Blair's Tory 'lies'\n \n Tony Blai...(cid:10)Label                                                    0(cid:10)Name: 8, dtype: object
#
# Text     Tories unveil quango blitz plans\n \n Plans to...(cid:10)Label                                                    0(cid:10)Name: 9, dtype: object
#
# Text     Hatfield executives go on trial\n \n Engineeri...(cid:10)Label                                                    0(cid:10)Name: 10, dtype: object
#
# Text     Howard rejects BNP's claim\n \n Tory leader Mi...(cid:10)Label                                                    0(cid:10)Name: 11, dtype: object
#
# Text     Howard unveils Tory asylum plans\n \n Tory pla...(cid:10)Label                                                    0(cid:10)Name: 12, dtype: object
#
# Text     Brown and Blair face new rift claims\n \n For ...(cid:10)Label                                                    0(cid:10)Name: 13, dtype: object
#
# Text     Tories plan migrant health checks\n \n Non-Eur...(cid:10)Label                                                    0(cid:10)Name: 14, dtype: object
#
# Text     Brown targets OAPs and homebuyers\n \n Gordon ...(cid:10)Label                                                    0(cid:10)Name: 15, dtype: object
#
# Text     Ministers deny care sums 'wrong'\n \n Minister...(cid:10)Label                                                    0(cid:10)Name: 16, dtype: object
#
# Text     Straw praises Kashmir moves\n \n The UK has we...(cid:10)Label                                                    0(cid:10)Name: 17, dtype: object
#
# Text     Turkey deal 'to help world peace'\n \n A deal ...(cid:10)Label                                                    0(cid:10)Name: 18, dtype: object
#
# Text     Goldsmith: 'I was not leant on'\n \n The attor...(cid:10)Label                                                    0(cid:10)Name: 19, dtype: object
#
# Text     Escaped prisoner report ordered\n \n First Min...(cid:10)Label                                                    0(cid:10)Name: 20, dtype: object
#
# Text     Analysis: No pain, no gain?\n \n He called it ...(cid:10)Label                                                    0(cid:10)Name: 21, dtype: object
#
# Text     Labour accused of 'EU propaganda'\n \n A "taxp...(cid:10)Label                                                    0(cid:10)Name: 22, dtype: object
#
# Text     Tories urge 'change at the top'\n \n Tory dele...(cid:10)Label                                                    0(cid:10)Name: 23, dtype: object
#
# Text     'Hitler' row over Welsh arts cash\n \n An arti...(cid:10)Label                                                    0(cid:10)Name: 24, dtype: object
#
# Text     Whitehall cuts 'ahead of target'\n \n Thousand...(cid:10)Label                                                    0(cid:10)Name: 25, dtype: object
#
# Text     Lib Dems demand new inquiry\n \n A judge shoul...(cid:10)Label                                                    0(cid:10)Name: 26, dtype: object
#
# Text     Ban on hunting comes into force\n \n Fox hunti...(cid:10)Label                                                    0(cid:10)Name: 27, dtype: object
#
# Text     MPs quiz aides over royal income\n \n Senior o...(cid:10)Label                                                    0(cid:10)Name: 28, dtype: object
#
# Text     Mayor will not retract Nazi jibe\n \n London m...(cid:10)Label                                                    0(cid:10)Name: 29, dtype: object
#
# Text     Lib Dems 'to target stamp duty'\n \n The Liber...(cid:10)Label                                                    0(cid:10)Name: 30, dtype: object
#
# Text     Mallon wades into NE vote battle\n \n Middlesb...(cid:10)Label                                                    0(cid:10)Name: 31, dtype: object
#
# Text     Labour faces 'cold calls' inquiry\n \n Labour ...(cid:10)Label                                                    0(cid:10)Name: 32, dtype: object
#
# Text     Blair backs 'pre-election budget'\n \n Tony Bl...(cid:10)Label                                                    0(cid:10)Name: 33, dtype: object
#
# Text     Final hunts held as ban looms\n \n Hunts in En...(cid:10)Label                                                    0(cid:10)Name: 34, dtype: object
#
# Text     Iraqis win death test case probe\n \n The fami...(cid:10)Label                                                    0(cid:10)Name: 35, dtype: object
#
# Text     Parties build up poll war chests\n \n The Labo...(cid:10)Label                                                    0(cid:10)Name: 36, dtype: object
#
# Text     England children's tsar appointed\n \n The fir...(cid:10)Label                                                    0(cid:10)Name: 37, dtype: object
#
# Text     Parties warned over 'grey vote'\n \n Political...(cid:10)Label                                                    0(cid:10)Name: 38, dtype: object
#
# Text     Tory leader 'cleared' over work\n \n Scottish ...(cid:10)Label                                                    0(cid:10)Name: 39, dtype: object
#
# Text     Labour trio 'had vote-rig factory'\n \n Three ...(cid:10)Label                                                    0(cid:10)Name: 40, dtype: object
#
# Text     New drink limit 'would cut toll'\n \n More liv...(cid:10)Label                                                    0(cid:10)Name: 41, dtype: object
#
# Text     Labour MP praises Tory campaign\n \n The Conse...(cid:10)Label                                                    0(cid:10)Name: 42, dtype: object
#
# Text     Lords wrong on detainees - Straw\n \n Jack Str...(cid:10)Label                                                    0(cid:10)Name: 43, dtype: object
#
# Text     Baron Kinnock makes Lords debut\n \n Former La...(cid:10)Label                                                    0(cid:10)Name: 44, dtype: object
#
# Text     Drive to 'save' festive holidays\n \n Efforts ...(cid:10)Label                                                    0(cid:10)Name: 45, dtype: object
#
# Text     How political squabbles snowball\n \n It's bec...(cid:10)Label                                                    0(cid:10)Name: 46, dtype: object
#
# Text     Muslim police stops 'more likely'\n \n UK Musl...(cid:10)Label                                                    0(cid:10)Name: 47, dtype: object
#
# Text     Falconer rebuts 'charade' claims\n \n Concessi...(cid:10)Label                                                    0(cid:10)Name: 48, dtype: object
#
# Text     Brown in appeal for Labour unity\n \n Gordon B...(cid:10)Label                                                    0(cid:10)Name: 49, dtype: object
#
# Text     Police probe BNP mosque leaflet\n \n Police ar...(cid:10)Label                                                    0(cid:10)Name: 50, dtype: object
#
# Text     Protect whistleblowers, TUC says\n \n The gove...(cid:10)Label                                                    0(cid:10)Name: 51, dtype: object
#
# Text     Sport betting rules in spotlight\n \n A group ...(cid:10)Label                                                    0(cid:10)Name: 52, dtype: object
#
# Text     Labour's Cunningham to stand down\n \n Veteran...(cid:10)Label                                                    0(cid:10)Name: 53, dtype: object
#
# Text     Blunkett tells of love and pain\n \n David Blu...(cid:10)Label                                                    0(cid:10)Name: 54, dtype: object
#
# Text     Brown to outline presidency goals\n \n Next ye...(cid:10)Label                                                    0(cid:10)Name: 55, dtype: object
#
# Text     Crucial decision on super-casinos\n \n A decis...(cid:10)Label                                                    0(cid:10)Name: 56, dtype: object
#
# Text     Blunkett sorry over murder plan\n \n David Blu...(cid:10)Label                                                    0(cid:10)Name: 57, dtype: object
#
# Text     Lib Dems' new election PR chief\n \n The Lib D...(cid:10)Label                                                    0(cid:10)Name: 58, dtype: object
#
# Text     Blair backs 'pre-election budget'\n \n Tony Bl...(cid:10)Label                                                    0(cid:10)Name: 59, dtype: object
#
# Text     Muslims discuss election concerns\n \n Issues ...(cid:10)Label                                                    0(cid:10)Name: 60, dtype: object
#
# Text     MPs demand 'Budget leak' answers\n \n Minister...(cid:10)Label                                                    0(cid:10)Name: 61, dtype: object
#
# Text     PM apology over jailings\n \n Tony Blair has a...(cid:10)Label                                                    0(cid:10)Name: 62, dtype: object
#
# Text     Terror powers expose 'tyranny'\n \n The Lord C...(cid:10)Label                                                    0(cid:10)Name: 63, dtype: object
#
# Text     BAA support ahead of court battle\n \n UK airp...(cid:10)Label                                                    0(cid:10)Name: 64, dtype: object
#
# Text     New rules tackle 'sham weddings'\n \n New rule...(cid:10)Label                                                    0(cid:10)Name: 65, dtype: object
#
# Text     UK troops on Ivory Coast standby\n \n Downing ...(cid:10)Label                                                    0(cid:10)Name: 66, dtype: object
#
# Text     Tory leader quits legal position\n \n David Mc...(cid:10)Label                                                    0(cid:10)Name: 67, dtype: object
#
# Text     'Debate needed' on donations cap\n \n A cap on...(cid:10)Label                                                    0(cid:10)Name: 68, dtype: object
#
# Text     Blair to face trust issue head on\n \n Tony Bl...(cid:10)Label                                                    0(cid:10)Name: 69, dtype: object
#
# Text     Butler launches attack on Blair\n \n Former ci...(cid:10)Label                                                    0(cid:10)Name: 70, dtype: object
#
# Text     'EU referendum could cost Â£80m'\n \n It could...(cid:10)Label                                                    0(cid:10)Name: 71, dtype: object
#
# Text     MPs issued with Blackberry threat\n \n MPs wil...(cid:10)Label                                                    0(cid:10)Name: 72, dtype: object
#
# Text     UK needs tax cuts, Tories insist\n \n A major ...(cid:10)Label                                                    0(cid:10)Name: 73, dtype: object
#
# Text     Burglar defence guidelines issued\n \n Househo...(cid:10)Label                                                    0(cid:10)Name: 74, dtype: object
#
# Text     Kennedy criticises 'unfair' taxes\n \n Gordon ...(cid:10)Label                                                    0(cid:10)Name: 75, dtype: object
#
# Text     Hunt ban support is 'in decline'\n \n Support ...(cid:10)Label                                                    0(cid:10)Name: 76, dtype: object
#
# Text     Pakistani women 'must not hide'\n \n Hiding wo...(cid:10)Label                                                    0(cid:10)Name: 77, dtype: object
#
# Text     Lib Dems predict 'best ever poll'\n \n The Lib...(cid:10)Label                                                    0(cid:10)Name: 78, dtype: object
#
# Text     Profile: David Miliband\n \n David Miliband's ...(cid:10)Label                                                    0(cid:10)Name: 79, dtype: object
#
# Text     Police urge pub closure power\n \n New powers ...(cid:10)Label                                                    0(cid:10)Name: 80, dtype: object
#
# Text     Boateng to step down at election\n \n Paul Boa...(cid:10)Label                                                    0(cid:10)Name: 81, dtype: object
#
# Text     Howard unveils election platform\n \n The Cons...(cid:10)Label                                                    0(cid:10)Name: 82, dtype: object
#
# Text     Labour plans maternity pay rise\n \n Maternity...(cid:10)Label                                                    0(cid:10)Name: 83, dtype: object
#
# Text     At a glance: Tory health checks\n \n The UK' o...(cid:10)Label                                                    0(cid:10)Name: 84, dtype: object
#
# Text     What the election should really be about?\n \n...(cid:10)Label                                                    0(cid:10)Name: 85, dtype: object
#
# Text     Could rivalry overshadow election?\n \n Tony B...(cid:10)Label                                                    0(cid:10)Name: 86, dtype: object
#
# Text     'More to do' on adult literacy\n \n The govern...(cid:10)Label                                                    0(cid:10)Name: 87, dtype: object
#
# Text     Brown 'proud of economy record'\n \n Gordon Br...(cid:10)Label                                                    0(cid:10)Name: 88, dtype: object
#
# Text     Kennedy questions trust of Blair\n \n Lib Dem ...(cid:10)Label                                                    0(cid:10)Name: 89, dtype: object
#
# Text     Tories attack burglar 'U-turns'\n \n Tory lead...(cid:10)Label                                                    0(cid:10)Name: 90, dtype: object
#
# Text     Tories reject rethink on axed MP\n \n Sacked M...(cid:10)Label                                                    0(cid:10)Name: 91, dtype: object
#
# Text     Tories pledge free sports lessons\n \n Childre...(cid:10)Label                                                    0(cid:10)Name: 92, dtype: object
#
# Text     Conservative backing for ID cards\n \n The Tor...(cid:10)Label                                                    0(cid:10)Name: 93, dtype: object
#
# Text     Choose hope over fear - Kennedy\n \n Voters wi...(cid:10)Label                                                    0(cid:10)Name: 94, dtype: object
#
# Text     Pre-poll clash on tax and spend\n \n Labour an...(cid:10)Label                                                    0(cid:10)Name: 95, dtype: object
#
# Text     Labour's election love-in\n \n Peace and love ...(cid:10)Label                                                    0(cid:10)Name: 96, dtype: object
#
# Text     Tories unveil quango blitz plans\n \n Plans to...(cid:10)Label                                                    0(cid:10)Name: 97, dtype: object
#
# Text     Tory leader urges Harry apology\n \n Prince Ha...(cid:10)Label                                                    0(cid:10)Name: 98, dtype: object
#
# Text     Terror detainees win Lords appeal\n \n Detaini...(cid:10)Label                                                    0(cid:10)Name: 99, dtype: object
#
# Text     Blair dismisses quit claim report\n \n Tony Bl...(cid:10)Label                                                    0(cid:10)Name: 100, dtype: object
#
# Text     Petrol duties frozen, Brown says\n \n Chancell...(cid:10)Label                                                    0(cid:10)Name: 101, dtype: object
#
# Text     Milburn defends poster campaign\n \n Labour's ...(cid:10)Label                                                    0(cid:10)Name: 102, dtype: object
#
# Text     Tory 'stalking horse' Meyer dies\n \n Sir Anth...(cid:10)Label                                                    0(cid:10)Name: 103, dtype: object
#
# Text     Goldsmith denies war advice claim\n \n The att...(cid:10)Label                                                    0(cid:10)Name: 104, dtype: object
#
# Text     Mrs Howard gets key election role\n \n Michael...(cid:10)Label                                                    0(cid:10)Name: 105, dtype: object
#
# Text     McConnell in 'drunk' remark row\n \n Scotland'...(cid:10)Label                                                    0(cid:10)Name: 106, dtype: object
#
# Text     Crisis 'ahead in social sciences'\n \n A natio...(cid:10)Label                                                    0(cid:10)Name: 107, dtype: object
#
# Text     Guantanamo four questioned\n \n The four Brito...(cid:10)Label                                                    0(cid:10)Name: 108, dtype: object
#
# Text     Kennedy calls for Iraq exit plans\n \n Tony Bl...(cid:10)Label                                                    0(cid:10)Name: 109, dtype: object
#
# Text     Boris opposes mayor apology\n \n Ken Livingsto...(cid:10)Label                                                    0(cid:10)Name: 110, dtype: object
#
# Text     Tory expert denies defeatism\n \n The Conserva...(cid:10)Label                                                    0(cid:10)Name: 111, dtype: object
#
# Text     Lib Dems target first-time buyers\n \n The Lib...(cid:10)Label                                                    0(cid:10)Name: 112, dtype: object
#
# Text     Immigration to be election issue\n \n Immigrat...(cid:10)Label                                                    0(cid:10)Name: 113, dtype: object
#
# Text     Blair sees greater Bush consensus\n \n George ...(cid:10)Label                                                    0(cid:10)Name: 114, dtype: object
#
# Text     Plaid MP's cottage arson claim\n \n A Plaid Cy...(cid:10)Label                                                    0(cid:10)Name: 115, dtype: object
#
# Text     Act on detention ruling, UK urged\n \n The gov...(cid:10)Label                                                    0(cid:10)Name: 116, dtype: object
#
# Text     Blair to face MPs amid feud talk\n \n Tony Bla...(cid:10)Label                                                    0(cid:10)Name: 117, dtype: object
#
# Text     UK rebate 'unjustified' - Chirac\n \n French p...(cid:10)Label                                                    0(cid:10)Name: 118, dtype: object
#
# Text     Howard dismisses Tory tax fears\n \n Michael H...(cid:10)Label                                                    0(cid:10)Name: 119, dtype: object
#
# Text     Campaign 'cold calls' questioned\n \n Labour a...(cid:10)Label                                                    0(cid:10)Name: 120, dtype: object
#
# Text     Kennedy predicts bigger turnout\n \n Voters' "...(cid:10)Label                                                    0(cid:10)Name: 121, dtype: object
#
# Text     MP's shock at long lost daughter\n \n Labour M...(cid:10)Label                                                    0(cid:10)Name: 122, dtype: object
#
# Text     More reforms ahead says Milburn\n \n Labour wi...(cid:10)Label                                                    0(cid:10)Name: 123, dtype: object
#
# Text     EU fraud clampdown urged\n \n EU member states...(cid:10)Label                                                    0(cid:10)Name: 124, dtype: object
#
# Text     UK's 'useless' quangos under fire\n \n The UK ...(cid:10)Label                                                    0(cid:10)Name: 125, dtype: object
#
# Text     Tories outlining policing plans\n \n Local com...(cid:10)Label                                                    0(cid:10)Name: 126, dtype: object
#
# Text     Brown names 16 March for Budget\n \n Chancello...(cid:10)Label                                                    0(cid:10)Name: 127, dtype: object
#
# Text     Hunt demo at Labour meeting\n \n Pro-hunt supp...(cid:10)Label                                                    0(cid:10)Name: 128, dtype: object
#
# Text     Mandelson warning to BBC\n \n The BBC should s...(cid:10)Label                                                    0(cid:10)Name: 129, dtype: object
#
# Text     Blair and Blunkett Sheffield trip\n \n Tony Bl...(cid:10)Label                                                    0(cid:10)Name: 130, dtype: object
#
# Text     Report attacks defence spending\n \n The Minis...(cid:10)Label                                                    0(cid:10)Name: 131, dtype: object
#
# Text     Nat Insurance to rise, say Tories\n \n Nationa...(cid:10)Label                                                    0(cid:10)Name: 132, dtype: object
#
# Text     Hague's six-figure earnings shown\n \n The rew...(cid:10)Label                                                    0(cid:10)Name: 133, dtype: object
#
# Text     UKIP outspent Labour on EU poll\n \n The UK In...(cid:10)Label                                                    0(cid:10)Name: 134, dtype: object
#
# Text     Howard taunts Blair over splits\n \n Tony Blai...(cid:10)Label                                                    0(cid:10)Name: 135, dtype: object
#
# Text     Campaign 'cold calls' questioned\n \n Labour a...(cid:10)Label                                                    0(cid:10)Name: 136, dtype: object
#
# Text     Brown ally rejects Budget spree\n \n Chancello...(cid:10)Label                                                    0(cid:10)Name: 137, dtype: object
#
# Text     Chancellor rallies Labour voters\n \n Gordon B...(cid:10)Label                                                    0(cid:10)Name: 138, dtype: object
#
# Text     Tories opposing 24-hour drinking\n \n The Tori...(cid:10)Label                                                    0(cid:10)Name: 139, dtype: object
#
# Text     Abbas 'will not tolerate' attacks\n \n Palesti...(cid:10)Label                                                    0(cid:10)Name: 140, dtype: object
#
# Text     Ex-PM Lord Callaghan dies aged 92\n \n Former ...(cid:10)Label                                                    0(cid:10)Name: 141, dtype: object
#
# Text     Howard pitches for UK ethnic vote\n \n Michael...(cid:10)Label                                                    0(cid:10)Name: 142, dtype: object
#
# Text     Blair ready to call election\n \n Tony Blair s...(cid:10)Label                                                    0(cid:10)Name: 143, dtype: object
#
# Text     EU China arms ban 'to be lifted'\n \n The EU e...(cid:10)Label                                                    0(cid:10)Name: 144, dtype: object
#
# Text     Minister defends hunting ban law\n \n The law ...(cid:10)Label                                                    0(cid:10)Name: 145, dtype: object
#
# Text     Child access laws shake-up\n \n Parents who re...(cid:10)Label                                                    0(cid:10)Name: 146, dtype: object
#
# Text     'Last chance' warning for voters\n \n People i...(cid:10)Label                                                    0(cid:10)Name: 147, dtype: object
#
# Text     Labour seeks to quell feud talk\n \n Labour's ...(cid:10)Label                                                    0(cid:10)Name: 148, dtype: object
#
# Text     MPs to debate 'euthanasia laws'\n \n MPs are p...(cid:10)Label                                                    0(cid:10)Name: 149, dtype: object
#
# Text     Kilroy unveils immigration policy\n \n Ex-chat...(cid:10)Label                                                    0(cid:10)Name: 150, dtype: object
#
# Text     Will the Budget bring out smiling voters?\n \n...(cid:10)Label                                                    0(cid:10)Name: 151, dtype: object
#
# Text     Kennedy to make temple address\n \n Charles Ke...(cid:10)Label                                                    0(cid:10)Name: 152, dtype: object
#
# Text     Labour targets 'hardcore truants'\n \n A fresh...(cid:10)Label                                                    0(cid:10)Name: 153, dtype: object
#
# Text     Blair prepares to name poll date\n \n Tony Bla...(cid:10)Label                                                    0(cid:10)Name: 154, dtype: object
#
# Text     'Debate needed' on donations cap\n \n A cap on...(cid:10)Label                                                    0(cid:10)Name: 155, dtype: object
#
# Text     Blair pledges unity to Labour MPs\n \n Tony Bl...(cid:10)Label                                                    0(cid:10)Name: 156, dtype: object
#
# Text     Thousands join strike in Wales\n \n Thousands ...(cid:10)Label                                                    0(cid:10)Name: 157, dtype: object
#
# Text     Blunkett unveils policing plans\n \n People co...(cid:10)Label                                                    0(cid:10)Name: 158, dtype: object
#
# Text     Concerns at school diploma plan\n \n Final app...(cid:10)Label                                                    0(cid:10)Name: 159, dtype: object
#
# Text     Security papers 'found in street'\n \n An inqu...(cid:10)Label                                                    0(cid:10)Name: 160, dtype: object
#
# Text     Opposition grows to house arrests\n \n The Con...(cid:10)Label                                                    0(cid:10)Name: 161, dtype: object
#
# Text     Peers debate Crown succession law\n \n Peers a...(cid:10)Label                                                    0(cid:10)Name: 162, dtype: object
#
# Text     New foot and mouth action urged\n \n A senior ...(cid:10)Label                                                    0(cid:10)Name: 163, dtype: object
#
# Text     Kennedy looks to election gains\n \n They may ...(cid:10)Label                                                    0(cid:10)Name: 164, dtype: object
#
# Text     Profile: David Blunkett\n \n Before he resigne...(cid:10)Label                                                    0(cid:10)Name: 165, dtype: object
#
# Text     E-University 'disgraceful waste'\n \n A failed...(cid:10)Label                                                    0(cid:10)Name: 166, dtype: object
#
# Text     Green fear for transport ballot\n \n The Green...(cid:10)Label                                                    0(cid:10)Name: 167, dtype: object
#
# Text     Howard 'truanted to play snooker'\n \n Conserv...(cid:10)Label                                                    0(cid:10)Name: 168, dtype: object
#
# Text     Blair 'damaged' by Blunkett row\n \n A majorit...(cid:10)Label                                                    0(cid:10)Name: 169, dtype: object
#
# Text     Tsunami 'won't divert Africa aid'\n \n UK aid ...(cid:10)Label                                                    0(cid:10)Name: 170, dtype: object
#
# Text     Police chief backs drinking move\n \n A chief ...(cid:10)Label                                                    0(cid:10)Name: 171, dtype: object
#
# Text     Clarke plans migrant point scheme\n \n Anyone ...(cid:10)Label                                                    0(cid:10)Name: 172, dtype: object
#
# Text     Malik rejects all-black MP lists\n \n A call f...(cid:10)Label                                                    0(cid:10)Name: 173, dtype: object
#
# Text     Blunkett hints at election call\n \n Ex-Home S...(cid:10)Label                                                    0(cid:10)Name: 174, dtype: object
#
# Text     Commons hunt protest charges\n \n Eight protes...(cid:10)Label                                                    0(cid:10)Name: 175, dtype: object
#
# Text     Labour attacked on Howard poster\n \n Labour h...(cid:10)Label                                                    0(cid:10)Name: 176, dtype: object
#
# Text     Amnesty chief laments war failure\n \n The lac...(cid:10)Label                                                    0(cid:10)Name: 177, dtype: object
#
# Text     Howard backs stem cell research\n \n Michael H...(cid:10)Label                                                    0(cid:10)Name: 178, dtype: object
#
# Text     Visa decision 'every 11 minutes'\n \n Visa pro...(cid:10)Label                                                    0(cid:10)Name: 179, dtype: object
#
# Text     Brown's poll campaign move denied\n \n The gov...(cid:10)Label                                                    0(cid:10)Name: 180, dtype: object
#
# Text     'No-one can define new hunt ban'\n \n The new ...(cid:10)Label                                                    0(cid:10)Name: 181, dtype: object
#
# Text     Labour in constituency race row\n \n Labour's ...(cid:10)Label                                                    0(cid:10)Name: 182, dtype: object
#
# Text     Brown calls for Â£5.5bn Aids fund\n \n Gordon ...(cid:10)Label                                                    0(cid:10)Name: 183, dtype: object
#
# Text     Blair and Brown criticised by MPs\n \n Labour ...(cid:10)Label                                                    0(cid:10)Name: 184, dtype: object
#
# Text     Kilroy-Silk attacked with slurry\n \n Euro MP ...(cid:10)Label                                                    0(cid:10)Name: 185, dtype: object
#
# Text     Howard denies split over ID cards\n \n Michael...(cid:10)Label                                                    0(cid:10)Name: 186, dtype: object
#
# Text     Talks aim to avert pension strike\n \n Talks a...(cid:10)Label                                                    0(cid:10)Name: 187, dtype: object
#
# Text     Assembly ballot papers 'missing'\n \n Hundreds...(cid:10)Label                                                    0(cid:10)Name: 188, dtype: object
#
# Text     Councils prepare to set tax rises\n \n Council...(cid:10)Label                                                    0(cid:10)Name: 189, dtype: object
#
# Text     Hospital suspends 'no Welsh' plan\n \n An Engl...(cid:10)Label                                                    0(cid:10)Name: 190, dtype: object
#
# Text     Galloway plea for hostage release\n \n Ex-Labo...(cid:10)Label                                                    0(cid:10)Name: 191, dtype: object
#
# Text     Asylum children to face returns\n \n The UK go...(cid:10)Label                                                    0(cid:10)Name: 192, dtype: object
#
# Text     'UK will stand firm on EU rebate'\n \n Britain...(cid:10)Label                                                    0(cid:10)Name: 193, dtype: object
#
# Text     Labour MPs' fears over squabbling\n \n If ther...(cid:10)Label                                                    0(cid:10)Name: 194, dtype: object
#
# Text     Jowell rejects 'Las Vegas' jibe\n \n The Secre...(cid:10)Label                                                    0(cid:10)Name: 195, dtype: object
#
# Text     BNP leader Nick Griffin arrested\n \n The lead...(cid:10)Label                                                    0(cid:10)Name: 196, dtype: object
#
# Text     What really divides the parties\n \n So what i...(cid:10)Label                                                    0(cid:10)Name: 197, dtype: object
#
# Text     Retirement age could be scrapped\n \n The "myt...(cid:10)Label                                                    0(cid:10)Name: 198, dtype: object
#
# Text     'Errors' doomed first Dome sale\n \n The initi...(cid:10)Label                                                    0(cid:10)Name: 199, dtype: object
#
# Text     Lib Dems target the student vote\n \n Students...(cid:10)Label                                                    0(cid:10)Name: 200, dtype: object
#
# Text     School sport 'is back', says PM\n \n Tony Blai...(cid:10)Label                                                    0(cid:10)Name: 201, dtype: object
#
# Text     'Nuclear dumpsite' plan attacked\n \n Plans to...(cid:10)Label                                                    0(cid:10)Name: 202, dtype: object
#
# Text     Visa row mandarin made Sir John\n \n The top c...(cid:10)Label                                                    0(cid:10)Name: 203, dtype: object
#
# Text     Citizenship event for 18s touted\n \n Citizens...(cid:10)Label                                                    0(cid:10)Name: 204, dtype: object
#
# Text     Women MPs reveal sexist taunts\n \n Women MPs ...(cid:10)Label                                                    0(cid:10)Name: 205, dtype: object
#
# Text     Nuclear strike 'key terror risk'\n \n The UK a...(cid:10)Label                                                    0(cid:10)Name: 206, dtype: object
#
# Text     UK youth 'interested' in politics\n \n The maj...(cid:10)Label                                                    0(cid:10)Name: 207, dtype: object
#
# Text     Peace demo appeal rejected\n \n Peace protesto...(cid:10)Label                                                    0(cid:10)Name: 208, dtype: object
#
# Text     Brown outlines third term vision\n \n Gordon B...(cid:10)Label                                                    0(cid:10)Name: 209, dtype: object
#
# Text     Blair defends terror law changes\n \n The prim...(cid:10)Label                                                    0(cid:10)Name: 210, dtype: object
#
# Text     Probe launched on Ken Nazi jibe\n \n An invest...(cid:10)Label                                                    0(cid:10)Name: 211, dtype: object
#
# Text     Conservative MP defects to Labour\n \n A Conse...(cid:10)Label                                                    0(cid:10)Name: 212, dtype: object
#
# Text     Kilroy launches 'Veritas' party\n \n Ex-BBC ch...(cid:10)Label                                                    0(cid:10)Name: 213, dtype: object
#
# Text     Parties warned over 'grey vote'\n \n Political...(cid:10)Label                                                    0(cid:10)Name: 214, dtype: object
#
# Text     'Few ready' for information act\n \n Thousands...(cid:10)Label                                                    0(cid:10)Name: 215, dtype: object
#
# Text     Kennedy questions trust of Blair\n \n Lib Dem ...(cid:10)Label                                                    0(cid:10)Name: 216, dtype: object
#
# Text     Howard attacks cost of asylum\n \n Michael How...(cid:10)Label                                                    0(cid:10)Name: 217, dtype: object
#
# Text     Cardinal criticises Iraq war cost\n \n Billion...(cid:10)Label                                                    0(cid:10)Name: 218, dtype: object
#
# Text     Jamieson issues warning to bigots\n \n Scotlan...(cid:10)Label                                                    0(cid:10)Name: 219, dtype: object
#
# Text     MP attacked by muggers in Kenya\n \n An MP has...(cid:10)Label                                                    0(cid:10)Name: 220, dtype: object
#
# Text     Parliament's record of scandal\n \n In a locke...(cid:10)Label                                                    0(cid:10)Name: 221, dtype: object
#
# Text     Defection timed to hit tax pledge\n \n With im...(cid:10)Label                                                    0(cid:10)Name: 222, dtype: object
#
# Text     Voters 'don't trust politicians'\n \n Eight ou...(cid:10)Label                                                    0(cid:10)Name: 223, dtype: object
#
# Text     Brown hits back in Blair rift row\n \n Gordon ...(cid:10)Label                                                    0(cid:10)Name: 224, dtype: object
#
# Text     Blair's hope for Blunkett return\n \n The even...(cid:10)Label                                                    0(cid:10)Name: 225, dtype: object
#
# Text     Fox attacks Blair's Tory 'lies'\n \n Tony Blai...(cid:10)Label                                                    0(cid:10)Name: 226, dtype: object
#
# Text     Lib Dems highlight problem debt\n \n People vu...(cid:10)Label                                                    0(cid:10)Name: 227, dtype: object
#
# Text     Taxes must be trusted - Kennedy\n \n Public tr...(cid:10)Label                                                    0(cid:10)Name: 228, dtype: object
#
# Text     Kennedy begins pre-election tour\n \n Liberal ...(cid:10)Label                                                    0(cid:10)Name: 229, dtype: object
#
# Text     Blair says mayor should apologise\n \n Tony Bl...(cid:10)Label                                                    0(cid:10)Name: 230, dtype: object
#
# Text     Sayeed to stand down as Tory MP\n \n Tory MP J...(cid:10)Label                                                    0(cid:10)Name: 231, dtype: object
#
# Text     'Best person' for top legal job\n \n The "best...(cid:10)Label                                                    0(cid:10)Name: 232, dtype: object
#
# Text     Labour pig poster 'anti-Semitic'\n \n The Labo...(cid:10)Label                                                    0(cid:10)Name: 233, dtype: object
#
# Text     Schools to take part in mock poll\n \n Record ...(cid:10)Label                                                    0(cid:10)Name: 234, dtype: object
#
# Text     Borders rail link campaign rally\n \n Campaign...(cid:10)Label                                                    0(cid:10)Name: 235, dtype: object
#
# Text     Housing plans criticised by MPs\n \n "Irrevers...(cid:10)Label                                                    0(cid:10)Name: 236, dtype: object
#
# Text     The memory driving Brown's mission\n \n The me...(cid:10)Label                                                    0(cid:10)Name: 237, dtype: object
#
# Text     Bid to cut court witness stress\n \n New targe...(cid:10)Label                                                    0(cid:10)Name: 238, dtype: object
#
# Text     Cabinet anger at Brown cash raid\n \n Minister...(cid:10)Label                                                    0(cid:10)Name: 239, dtype: object
#
# Text     Blair rejects Tory terror offer\n \n Tony Blai...(cid:10)Label                                                    0(cid:10)Name: 240, dtype: object
#
# Text     Top Tories on Lib Dem 'hit list'\n \n The Libe...(cid:10)Label                                                    0(cid:10)Name: 241, dtype: object
#
# Text     Clarke defends terror detentions\n \n The home...(cid:10)Label                                                    0(cid:10)Name: 242, dtype: object
#
# Text     Hague 'given up' his PM ambition\n \n Former C...(cid:10)Label                                                    0(cid:10)Name: 243, dtype: object
#
# Text     Tories attack EU asylum moves\n \n David Blunk...(cid:10)Label                                                    0(cid:10)Name: 244, dtype: object
#
# Text     UKIP candidate suspended\n \n Eurosceptic part...(cid:10)Label                                                    0(cid:10)Name: 245, dtype: object
#
# Text     Brown shrugs off economy fears\n \n Gordon Bro...(cid:10)Label                                                    0(cid:10)Name: 246, dtype: object
#
# Text     Game warnings 'must be clearer'\n \n Violent v...(cid:10)Label                                                    0(cid:10)Name: 247, dtype: object
#
# Text     'Super union' merger plan touted\n \n Two of B...(cid:10)Label                                                    0(cid:10)Name: 248, dtype: object
#
# Text     Faith schools citizenship warning\n \n Schools...(cid:10)Label                                                    0(cid:10)Name: 249, dtype: object
#
# Text     Blair told to double overseas aid\n \n Tony Bl...(cid:10)Label                                                    0(cid:10)Name: 250, dtype: object
#
# Text     Galloway targets 'New Labour' MP\n \n George G...(cid:10)Label                                                    0(cid:10)Name: 251, dtype: object
#
# Text     UK helps raped Rwandan women\n \n Britain is t...(cid:10)Label                                                    0(cid:10)Name: 252, dtype: object
#
# Text     'Poll Idols' face first hurdles\n \n Vote For ...(cid:10)Label                                                    0(cid:10)Name: 253, dtype: object
#
# Text     Kennedy's cautious optimism\n \n Charles Kenne...(cid:10)Label                                                    0(cid:10)Name: 254, dtype: object
#
# Text     Parties' plans for council tax\n \n Anger at c...(cid:10)Label                                                    0(cid:10)Name: 255, dtype: object
#
# Text     Correction agency plans dropped\n \n Plans to ...(cid:10)Label                                                    0(cid:10)Name: 256, dtype: object
#
# Text     UKIP's secret weapon?\n \n By any measure, New...(cid:10)Label                                                    0(cid:10)Name: 257, dtype: object
#
# Text     Hewitt decries 'career sexism'\n \n Plans to e...(cid:10)Label                                                    0(cid:10)Name: 258, dtype: object
#
# Text     Ministers 'naive' over phone-taps\n \n The gov...(cid:10)Label                                                    0(cid:10)Name: 259, dtype: object
#
# Text     Tory leader unveils spending plan\n \n Tory le...(cid:10)Label                                                    0(cid:10)Name: 260, dtype: object
#
# Text     Stalemate in pension strike talks\n \n Talks a...(cid:10)Label                                                    0(cid:10)Name: 261, dtype: object
#
# Text     Blair rejects Iraq advice calls\n \n Tony Blai...(cid:10)Label                                                    0(cid:10)Name: 262, dtype: object
#
# Text     Plan to give elderly care control\n \n Elderly...(cid:10)Label                                                    0(cid:10)Name: 263, dtype: object
#
# Text     Brown outlines third term vision\n \n Gordon B...(cid:10)Label                                                    0(cid:10)Name: 264, dtype: object
#
# Text     Blair hails Turkey-EU talks deal\n \n Tony Bla...(cid:10)Label                                                    0(cid:10)Name: 265, dtype: object
#
# Text     Howard hits back at mongrel jibe\n \n Michael ...(cid:10)Label                                                    0(cid:10)Name: 266, dtype: object
#
# Text     McConnell details Scots wave toll\n \n At leas...(cid:10)Label                                                    0(cid:10)Name: 267, dtype: object
#
# Text     Straw backs ending China embargo\n \n UK Forei...(cid:10)Label                                                    0(cid:10)Name: 268, dtype: object
#
# Text     Labour's 'EU propaganda'\n \n A "taxpayer subs...(cid:10)Label                                                    0(cid:10)Name: 269, dtype: object
#
# Text     Whitehall shredding increasing - Tories\n \n C...(cid:10)Label                                                    0(cid:10)Name: 270, dtype: object
#
# Text     Guantanamo man 'suing government'\n \n A Briti...(cid:10)Label                                                    0(cid:10)Name: 271, dtype: object
#
# Text     Mandelson warns BBC on Campbell\n \n The BBC s...(cid:10)Label                                                    0(cid:10)Name: 272, dtype: object
#
# Text     Lawyer attacks anti-terror laws\n \n A senior ...(cid:10)Label                                                    0(cid:10)Name: 273, dtype: object
#
# Text     No election TV debate, says Blair\n \n Tony Bl...(cid:10)Label                                                    0(cid:10)Name: 274, dtype: object
#
# Text     Lib Dems unveil election slogan\n \n The Liber...(cid:10)Label                                                    0(cid:10)Name: 275, dtype: object
#
# Text     Blair moves to woo Jewish voters\n \n Tony Bla...(cid:10)Label                                                    0(cid:10)Name: 276, dtype: object
#
# Text     MPs assess Scots fishing industry\n \n A group...(cid:10)Label                                                    0(cid:10)Name: 277, dtype: object
#
# Text     Candidate resigns over BNP link\n \n A prospec...(cid:10)Label                                                    0(cid:10)Name: 278, dtype: object
#
# ...
#
# Text     US in EU tariff chaos trade row\n \n The US ha...(cid:10)Label                                                    4(cid:10)Name: 2125, dtype: object
#
# Text     Deutsche Boerse set to 'woo' LSE\n \n Bosses o...(cid:10)Label                                                    4(cid:10)Name: 2126, dtype: object
#
# Text     Tobacco giants hail court ruling\n \n US tobac...(cid:10)Label                                                    4(cid:10)Name: 2127, dtype: object
#
# Text     GE sees 'excellent' world economy\n \n US behe...(cid:10)Label                                                    4(cid:10)Name: 2128, dtype: object
#
# Text     Yukos seeks court action on sale\n \n Yukos wi...(cid:10)Label                                                    4(cid:10)Name: 2129, dtype: object
#
# Text     Pernod takeover talk lifts Domecq\n \n Shares ...(cid:10)Label                                                    4(cid:10)Name: 2130, dtype: object
#
# Text     Euro firms miss out on optimism\n \n More than...(cid:10)Label                                                    4(cid:10)Name: 2131, dtype: object
#
# Text     Quake's economic costs emerging\n \n Asian gov...(cid:10)Label                                                    4(cid:10)Name: 2132, dtype: object
#
# Text     Malaysia lifts Islamic bank limit\n \n Malaysi...(cid:10)Label                                                    4(cid:10)Name: 2133, dtype: object
#
# Text     Business confidence dips in Japan\n \n Busines...(cid:10)Label                                                    4(cid:10)Name: 2134, dtype: object
#
# Text     House prices show slight increase\n \n Prices ...(cid:10)Label                                                    4(cid:10)Name: 2135, dtype: object
#
# Text     Parmalat founder offers apology\n \n The found...(cid:10)Label                                                    4(cid:10)Name: 2136, dtype: object
#
# Text     Electronics firms eye plasma deal\n \n Consume...(cid:10)Label                                                    4(cid:10)Name: 2137, dtype: object
#
# Text     Orange colour clash set for court\n \n A row o...(cid:10)Label                                                    4(cid:10)Name: 2138, dtype: object
#
# Text     Weak end-of-year sales hit Next\n \n Next has ...(cid:10)Label                                                    4(cid:10)Name: 2139, dtype: object
#
# Text     GM, Ford cut output as sales fall\n \n US car ...(cid:10)Label                                                    4(cid:10)Name: 2140, dtype: object
#
# Text     Ukraine steel sell-off 'illegal'\n \n The cont...(cid:10)Label                                                    4(cid:10)Name: 2141, dtype: object
#
# Text     Axa Sun Life cuts bonus payments\n \n Life ins...(cid:10)Label                                                    4(cid:10)Name: 2142, dtype: object
#
# Text     Senior Fannie Mae bosses resign\n \n The two m...(cid:10)Label                                                    4(cid:10)Name: 2143, dtype: object
#
# Text     Car giant hit by Mercedes slump\n \n A slump i...(cid:10)Label                                                    4(cid:10)Name: 2144, dtype: object
#
# Text     US interest rates increased to 2%\n \n US inte...(cid:10)Label                                                    4(cid:10)Name: 2145, dtype: object
#
# Text     US data sparks inflation worries\n \n Wholesal...(cid:10)Label                                                    4(cid:10)Name: 2146, dtype: object
#
# Text     Retail sales show festive fervour\n \n UK reta...(cid:10)Label                                                    4(cid:10)Name: 2147, dtype: object
#
# Text     Bank payout to Pinochet victims\n \n A US bank...(cid:10)Label                                                    4(cid:10)Name: 2148, dtype: object
#
# Text     BT offers equal access to rivals\n \n BT has m...(cid:10)Label                                                    4(cid:10)Name: 2149, dtype: object
#
# Text     Share boost for feud-hit Reliance\n \n The boa...(cid:10)Label                                                    4(cid:10)Name: 2150, dtype: object
#
# Text     Weak data buffets French economy\n \n A batch ...(cid:10)Label                                                    4(cid:10)Name: 2151, dtype: object
#
# Text     Israeli economy picking up pace\n \n Israel's ...(cid:10)Label                                                    4(cid:10)Name: 2152, dtype: object
#
# Text     Tsunami cost hits Jakarta shares\n \n The stoc...(cid:10)Label                                                    4(cid:10)Name: 2153, dtype: object
#
# Text     Egypt to sell off state-owned bank\n \n The Eg...(cid:10)Label                                                    4(cid:10)Name: 2154, dtype: object
#
# Text     Bank set to leave rates on hold\n \n UK intere...(cid:10)Label                                                    4(cid:10)Name: 2155, dtype: object
#
# Text     Safety alert as GM recalls cars\n \n The world...(cid:10)Label                                                    4(cid:10)Name: 2156, dtype: object
#
# Text     Brazil plays down Varig rescue\n \n The Brazil...(cid:10)Label                                                    4(cid:10)Name: 2157, dtype: object
#
# Text     UK interest rates held at 4.75%\n \n The Bank ...(cid:10)Label                                                    4(cid:10)Name: 2158, dtype: object
#
# Text     EU aiming to fuel development aid\n \n Europea...(cid:10)Label                                                    4(cid:10)Name: 2159, dtype: object
#
# Text     US seeks new $280bn smoker ruling\n \n The US ...(cid:10)Label                                                    4(cid:10)Name: 2160, dtype: object
#
# Text     Mixed Christmas for US retailers\n \n US retai...(cid:10)Label                                                    4(cid:10)Name: 2161, dtype: object
#
# Text     Fiat mulls Ferrari market listing\n \n Ferrari...(cid:10)Label                                                    4(cid:10)Name: 2162, dtype: object
#
# Text     Indy buys into India paper\n \n Irish publishi...(cid:10)Label                                                    4(cid:10)Name: 2163, dtype: object
#
# Text     EU-US seeking deal on air dispute\n \n The EU ...(cid:10)Label                                                    4(cid:10)Name: 2164, dtype: object
#
# Text     UK firm faces Venezuelan land row\n \n Venezue...(cid:10)Label                                                    4(cid:10)Name: 2165, dtype: object
#
# Text     Asia shares defy post-quake gloom\n \n Thailan...(cid:10)Label                                                    4(cid:10)Name: 2166, dtype: object
#
# Text     EMI shares hit by profit warning\n \n Shares i...(cid:10)Label                                                    4(cid:10)Name: 2167, dtype: object
#
# Text     Enron bosses in $168m payout\n \n Eighteen for...(cid:10)Label                                                    4(cid:10)Name: 2168, dtype: object
#
# Text     US regulator to rule on pain drug\n \n US food...(cid:10)Label                                                    4(cid:10)Name: 2169, dtype: object
#
# Text     Russia gets investment blessing\n \n Soaring o...(cid:10)Label                                                    4(cid:10)Name: 2170, dtype: object
#
# Text     Lufthansa flies back to profit\n \n German air...(cid:10)Label                                                    4(cid:10)Name: 2171, dtype: object
#
# Text     Rich grab half Colombia poor fund\n \n Half of...(cid:10)Label                                                    4(cid:10)Name: 2172, dtype: object
#
# Text     SA unveils 'more for all' budget\n \n The Sout...(cid:10)Label                                                    4(cid:10)Name: 2173, dtype: object
#
# Text     IMF agrees fresh Turkey funding\n \n Turkey ha...(cid:10)Label                                                    4(cid:10)Name: 2174, dtype: object
#
# Text     Ukraine revisits state sell-offs\n \n Ukraine ...(cid:10)Label                                                    4(cid:10)Name: 2175, dtype: object
#
# Text     GSK aims to stop Aids profiteers\n \n One of t...(cid:10)Label                                                    4(cid:10)Name: 2176, dtype: object
#
# Text     HealthSouth ex-boss goes on trial\n \n The for...(cid:10)Label                                                    4(cid:10)Name: 2177, dtype: object
#
# Text     Weak dollar hits Reuters\n \n Revenues at medi...(cid:10)Label                                                    4(cid:10)Name: 2178, dtype: object
#
# Text     Iranian MPs threaten mobile deal\n \n Turkey's...(cid:10)Label                                                    4(cid:10)Name: 2179, dtype: object
#
# Text     Gazprom 'in $36m back-tax claim'\n \n The nucl...(cid:10)Label                                                    4(cid:10)Name: 2180, dtype: object
#
# Text     German growth goes into reverse\n \n Germany's...(cid:10)Label                                                    4(cid:10)Name: 2181, dtype: object
#
# Text     Ebbers 'aware' of WorldCom fraud\n \n Former W...(cid:10)Label                                                    4(cid:10)Name: 2182, dtype: object
#
# Text     India widens access to telecoms\n \n India has...(cid:10)Label                                                    4(cid:10)Name: 2183, dtype: object
#
# Text     Ukraine trims privatisation check\n \n Ukraine...(cid:10)Label                                                    4(cid:10)Name: 2184, dtype: object
#
# Text     US to probe airline travel chaos\n \n The US g...(cid:10)Label                                                    4(cid:10)Name: 2185, dtype: object
#
# Text     SEC to rethink post-Enron rules\n \n The US st...(cid:10)Label                                                    4(cid:10)Name: 2186, dtype: object
#
# Text     Bank opts to leave rates on hold\n \n The Bank...(cid:10)Label                                                    4(cid:10)Name: 2187, dtype: object
#
# Text     UK Coal plunges into deeper loss\n \n Shares i...(cid:10)Label                                                    4(cid:10)Name: 2188, dtype: object
#
# Text     Jobs go at Oracle after takeover\n \n Oracle h...(cid:10)Label                                                    4(cid:10)Name: 2189, dtype: object
#
# Text     US economy still growing says Fed\n \n Most ar...(cid:10)Label                                                    4(cid:10)Name: 2190, dtype: object
#
# Text     China bans new tobacco factories\n \n The worl...(cid:10)Label                                                    4(cid:10)Name: 2191, dtype: object
#
# Text     Japan bank shares up on link talk\n \n Shares ...(cid:10)Label                                                    4(cid:10)Name: 2192, dtype: object
#
# Text     Peugeot deal boosts Mitsubishi\n \n Struggling...(cid:10)Label                                                    4(cid:10)Name: 2193, dtype: object
#
# Text     Venezuela reviews foreign deals\n \n Venezuela...(cid:10)Label                                                    4(cid:10)Name: 2194, dtype: object
#
# Text     Khodorkovsky quits Yukos shares\n \n Jailed ty...(cid:10)Label                                                    4(cid:10)Name: 2195, dtype: object
#
# Text     VW considers opening Indian plant\n \n Volkswa...(cid:10)Label                                                    4(cid:10)Name: 2196, dtype: object
#
# Text     UK young top Euro earnings league\n \n British...(cid:10)Label                                                    4(cid:10)Name: 2197, dtype: object
#
# Text     Chinese dam firm 'defies Beijing'\n \n The Chi...(cid:10)Label                                                    4(cid:10)Name: 2198, dtype: object
#
# Text     Battered dollar hits another low\n \n The doll...(cid:10)Label                                                    4(cid:10)Name: 2199, dtype: object
#
# Text     Euronext joins bid battle for LSE\n \n Pan-Eur...(cid:10)Label                                                    4(cid:10)Name: 2200, dtype: object
#
# Text     Air China in $1bn London listing\n \n China's ...(cid:10)Label                                                    4(cid:10)Name: 2201, dtype: object
#
# Text     China continues breakneck growth\n \n China's ...(cid:10)Label                                                    4(cid:10)Name: 2202, dtype: object
#
# Text     Brewers' profits lose their fizz\n \n Heineken...(cid:10)Label                                                    4(cid:10)Name: 2203, dtype: object
#
# Text     'Strong dollar' call halts slide\n \n The US d...(cid:10)Label                                                    4(cid:10)Name: 2204, dtype: object
#
# Text     Barclays profits hit record level\n \n Barclay...(cid:10)Label                                                    4(cid:10)Name: 2205, dtype: object
#
# Text     Asian banks halt dollar's slide\n \n The dolla...(cid:10)Label                                                    4(cid:10)Name: 2206, dtype: object
#
# Text     Venezuela and China sign oil deal\n \n Venezue...(cid:10)Label                                                    4(cid:10)Name: 2207, dtype: object
#
# Text     UK homes hit Â£3.3 trillion total\n \n The val...(cid:10)Label                                                    4(cid:10)Name: 2208, dtype: object
#
# Text     China's Shanda buys stake in Sina\n \n Chinese...(cid:10)Label                                                    4(cid:10)Name: 2209, dtype: object
#
# Text     EU 'too slow' on economic reforms\n \n Most EU...(cid:10)Label                                                    4(cid:10)Name: 2210, dtype: object
#
# Text     Economy 'strong' in election year\n \n UK busi...(cid:10)Label                                                    4(cid:10)Name: 2211, dtype: object
#
# Text     Saab to build Cadillacs in Sweden\n \n General...(cid:10)Label                                                    4(cid:10)Name: 2212, dtype: object
#
# Text     Bad weather hits Nestle sales\n \n A combinati...(cid:10)Label                                                    4(cid:10)Name: 2213, dtype: object
#
# Text     US Ahold suppliers face charges\n \n US prosec...(cid:10)Label                                                    4(cid:10)Name: 2214, dtype: object
#
# Text     Banker loses sexism claim\n \n A former execut...(cid:10)Label                                                    4(cid:10)Name: 2215, dtype: object
#
# Text     EC calls truce in deficit battle\n \n The Euro...(cid:10)Label                                                    4(cid:10)Name: 2216, dtype: object
#
# Text     Japanese growth grinds to a halt\n \n Growth i...(cid:10)Label                                                    4(cid:10)Name: 2217, dtype: object
#
# Text     Tate & Lyle boss bags top award\n \n Tate & Ly...(cid:10)Label                                                    4(cid:10)Name: 2218, dtype: object
#
# Text     Stock market eyes Japan recovery\n \n Japanese...(cid:10)Label                                                    4(cid:10)Name: 2219, dtype: object
#
# Text     India opens skies to competition\n \n India wi...(cid:10)Label                                                    4(cid:10)Name: 2220, dtype: object
#
# Text     Yukos bankruptcy 'not US matter'\n \n Russian ...(cid:10)Label                                                    4(cid:10)Name: 2221, dtype: object
#
# Text     Survey confirms property slowdown\n \n Governm...(cid:10)Label                                                    4(cid:10)Name: 2222, dtype: object
#
# Text     High fuel prices hit BA's profits\n \n British...(cid:10)Label                                                    4(cid:10)Name: 2223, dtype: object
#
# Text     US trade gap hits record in 2004\n \n The gap ...(cid:10)Label                                                    4(cid:10)Name: 2224, dtype: object

# %%
#downloading

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# True

# %% [markdown]
#     TOKENIZATION:

# %%
sentence_tokens=nltk.sent_tokenize(text)
word_tokens=nltk.word_tokenize(text)

# %%
print(sentence_tokens)
# Out:
# ['Text     Budget to set scene for election\\n \\n Gordon B...(cid:10)Label                                                    0(cid:10)Name: 0, dtype: object\n\nText     Army chiefs in regiments decision\\n \\n Militar...(cid:10)Label                                                    0(cid:10)Name: 1, dtype: object\n\nText     Howard denies split over ID cards\\n \\n Michael...(cid:10)Label                                                    0(cid:10)Name: 2, dtype: object\n\nText     Observers to monitor UK election\\n \\n Minister...(cid:10)Label                                                    0(cid:10)Name: 3, dtype: object\n\nText     Kilroy names election seat target\\n \\n Ex-chat...(cid:10)Label                                                    0(cid:10)Name: 4, dtype: object\n\nText     Donor attacks Blair-Brown \'feud\'\\n \\n The repo...(cid:10)Label                                                    0(cid:10)Name: 5, dtype: object\n\nText     Research fears over Kelly\'s views\\n \\n Scienti...(cid:10)Label                                                    0(cid:10)Name: 6, dtype: object\n\nText     Chancellor rallies Labour voters\\n \\n Gordon B...(cid:10)Label                                                    0(cid:10)Name: 7, dtype: object\n\nText     Fox attacks Blair\'s Tory \'lies\'\\n \\n Tony Blai...(cid:10)Label                                                    0(cid:10)Name: 8, dtype: object\n\nText     Tories unveil quango blitz plans\\n \\n Plans to...(cid:10)Label                                                    0(cid:10)Name: 9, dtype: object\n\nText     Hatfield executives go on trial\\n \\n Engineeri...(cid:10)Label                                                    0(cid:10)Name: 10, dtype: object\n\nText     Howard rejects BNP\'s claim\\n \\n Tory leader Mi...(cid:10)Label                                                    0(cid:10)Name: 11, dtype: object\n\nText     Howard unveils Tory asylum plans\\n \\n Tory pla...(cid:10)Label                                                    0(cid:10)Name: 12, dtype: object\n\nText     Brown and Blair face new rift claims\\n \\n For ...(cid:10)Label                                                    0(cid:10)Name: 13, dtype: object\n\nText     Tories plan migrant health checks\\n \\n Non-Eur...(cid:10)Label                                                    0(cid:10)Name: 14, dtype: object\n\nText     Brown targets OAPs and homebuyers\\n \\n Gordon ...(cid:10)Label                                                    0(cid:10)Name: 15, dtype: object\n\nText     Ministers deny care sums \'wrong\'\\n \\n Minister...(cid:10)Label                                                    0(cid:10)Name: 16, dtype: object\n\nText     Straw praises Kashmir moves\\n \\n The UK has we...(cid:10)Label                                                    0(cid:10)Name: 17, dtype: object\n\nText     Turkey deal \'to help world peace\'\\n \\n A deal ...(cid:10)Label                                                    0(cid:10)Name: 18, dtype: object\n\nText     Goldsmith: \'I was not leant on\'\\n \\n The attor...(cid:10)Label                                                    0(cid:10)Name: 19, dtype: object\n\nText     Escaped prisoner report ordered\\n \\n First Min...(cid:10)Label                                                    0(cid:10)Name: 20, dtype: object\n\nText     Analysis: No pain, no gain?\\n \\n He called it ...(cid:10)Label                                                    0(cid:10)Name: 21, dtype: object\n\nText     Labour accused of \'EU propaganda\'\\n \\n A "taxp...(cid:10)Label                                                    0(cid:10)Name: 22, dtype: object\n\nText     Tories urge \'change at the top\'\\n \\n Tory dele...(cid:10)Label                                                    0(cid:10)Name: 23, dtype: object\n\nText     \'Hitler\' row over Welsh arts cash\\n \\n An arti...(cid:10)Label                                                     ...

# %%
print(word_tokens)
# Out:
# ['Text', 'Budget', 'to', 'set', 'scene', 'for', 'election\\n', '\\n', 'Gordon', 'B', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '0', ',', 'dtype', ':', 'object', 'Text', 'Army', 'chiefs', 'in', 'regiments', 'decision\\n', '\\n', 'Militar', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '1', ',', 'dtype', ':', 'object', 'Text', 'Howard', 'denies', 'split', 'over', 'ID', 'cards\\n', '\\n', 'Michael', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '2', ',', 'dtype', ':', 'object', 'Text', 'Observers', 'to', 'monitor', 'UK', 'election\\n', '\\n', 'Minister', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '3', ',', 'dtype', ':', 'object', 'Text', 'Kilroy', 'names', 'election', 'seat', 'target\\n', '\\n', 'Ex-chat', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '4', ',', 'dtype', ':', 'object', 'Text', 'Donor', 'attacks', 'Blair-Brown', "'feud'\\n", '\\n', 'The', 'repo', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '5', ',', 'dtype', ':', 'object', 'Text', 'Research', 'fears', 'over', 'Kelly', "'s", 'views\\n', '\\n', 'Scienti', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '6', ',', 'dtype', ':', 'object', 'Text', 'Chancellor', 'rallies', 'Labour', 'voters\\n', '\\n', 'Gordon', 'B', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '7', ',', 'dtype', ':', 'object', 'Text', 'Fox', 'attacks', 'Blair', "'s", 'Tory', "'lies'\\n", '\\n', 'Tony', 'Blai', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '8', ',', 'dtype', ':', 'object', 'Text', 'Tories', 'unveil', 'quango', 'blitz', 'plans\\n', '\\n', 'Plans', 'to', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '9', ',', 'dtype', ':', 'object', 'Text', 'Hatfield', 'executives', 'go', 'on', 'trial\\n', '\\n', 'Engineeri', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '10', ',', 'dtype', ':', 'object', 'Text', 'Howard', 'rejects', 'BNP', "'s", 'claim\\n', '\\n', 'Tory', 'leader', 'Mi', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '11', ',', 'dtype', ':', 'object', 'Text', 'Howard', 'unveils', 'Tory', 'asylum', 'plans\\n', '\\n', 'Tory', 'pla', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '12', ',', 'dtype', ':', 'object', 'Text', 'Brown', 'and', 'Blair', 'face', 'new', 'rift', 'claims\\n', '\\n', 'For', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '13', ',', 'dtype', ':', 'object', 'Text', 'Tories', 'plan', 'migrant', 'health', 'checks\\n', '\\n', 'Non-Eur', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '14', ',', 'dtype', ':', 'object', 'Text', 'Brown', 'targets', 'OAPs', 'and', 'homebuyers\\n', '\\n', 'Gordon', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '15', ',', 'dtype', ':', 'object', 'Text', 'Ministers', 'deny', 'care', 'sums', "'wrong'\\n", '\\n', 'Minister', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '16', ',', 'dtype', ':', 'object', 'Text', 'Straw', 'praises', 'Kashmir', 'moves\\n', '\\n', 'The', 'UK', 'has', 'we', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '17', ',', 'dtype', ':', 'object', 'Text', 'Turkey', 'deal', "'to", 'help', 'world', "peace'\\n", '\\n', 'A', 'deal', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '18', ',', 'dtype', ':', 'object', 'Text', 'Goldsmith', ':', "'I", 'was', 'not', 'leant', "on'\\n", '\\n', 'The', 'attor', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '19', ',', 'dtype', ':', 'object', 'Text', 'Escaped', 'prisoner', 'report', 'ordered\\n', '\\n', 'First', 'Min', '...', '(', 'cid:10', ')', 'Label', '0', '(', 'cid:10', ')', 'Name', ':', '20', ',', 'dtype', ':', 'object', 'Text', 'Analysis', ':', ...

# %% [markdown]
#     LEMMATIZATION:

# %%
nltk.download('wordnet')
lemm=nltk.stem.WordNetLemmatizer()
def LemTokens(tokens):
    return [lemm.lemmatize(token) for token in tokens]

remove_punct_dict=dict((ord(punct),None) for punct in string.punctuation)
def LemNormalize(text):
    return LemTokens(nltk.word_tokenize(text.lower().translate(remove_punct_dict)))
# Out:
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
#     CHATBOT INTERFACE:

# %%
greet_inputs=('hello','hi','whassup','namaste','kemchoo','how are you')
greet_responses=('hi','hey there',' i am fine', 'good','me too')
def greet(sentence):
    for word in sentence.split():
        if word.lower() in greet_inputs:
            return random.choice(greet_responses)

# %% [markdown]
# TfIDF VECTORIZER:

# %%
from sklearn.feature_extraction.text  import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
#     BUILDING CHATFLOW:

# %%
def response(user_response):
    robot_response= ' '
    TfidVec=TfidfVectorizer(tokenizer=LemNormalize,stop_words='english')
    tfidf=TfidVec.fit_transform(sentence_tokens)
    vals=cosine_similarity(tfidf[-1],tfidf)
    idx=vals.argsort()[0][-2]
    flat=vals.flatten()
    flat.sort()
    req_tfidf=flat[-2]
    if(req_tfidf==0):
        robot_response=robot_response+ "I am sorry.Unable to understand!"
        return robot_response
    else:
        robot_response=robot_response+sentence_tokens[idx]
        return robot_response

# %% [markdown]
#     RESPONSE GENERATION:

# %%
flag = True 
print("Hello I am retreivel learning chatbot please type your text after greeting to me for ending convo type bye!")
while(flag==True):
    user_response=input()
    user_response=user_response.lower()
    if(user_response!='bye'):
        if(user_response=='thank you' or user_response=='thanks'):
            flag=True
            print('Bot: You are welcome!')
        else:
            if(greet(user_response) !=None):
               print('Bot:' + greet(user_response))
            else:
               sentence_tokens.append(user_response)
               word_tokens=nltk.word_tokenize(user_response)
               final_words=list(set(word_tokens))
               print('Bot:',end='')
               print(response(user_response))
               sentence_tokens.remove(user_response)
    else:
               flag = False
               print('Bot: Goodbye!')
# Out:
# Hello I am retreivel learning chatbot please type your text after greeting to me for ending convo type bye!
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# Cell In[18], line 4
#       2 print("Hello I am retreivel learning chatbot please type your text after greeting to me for ending convo type bye!")
#       3 while(flag==True):
# ----> 4     user_response=input()
#       5     user_response=user_response.lower()
#       6     if(user_response!='bye'):
#
# File /opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py:1261, in Kernel.raw_input(self, prompt)
#    1259 if not self._allow_stdin:
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
# -> 1261     raise StdinNotImplementedError(msg)
#    1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.
